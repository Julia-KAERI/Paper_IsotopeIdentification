# %%
using XLSX, DataFrames, CSV

# %%
xf = XLSX.readxlsx("Figure_data.xlsx")
# Out:
# XLSXFile("Figure_data.xlsx") containing 10 Worksheets
#             sheetname size          range
# -------------------------------------------------
#         Fig01_BKG+REF 256x4         A1:D256
#              Fig02_CS 256x4         A1:D256
#             Fig03_CSN 256x4         A1:D256
#           Fig04_Mixed 256x5         A1:E256
#            Fig05_CSRN 256x4         A1:D256
#           Fig06_Mixed 256x5         A1:E256
#          Fig07_FI_Spe 256x4         A1:D256
#          Fig08_FI_CSN 256x4         A1:D256
#         Fig09_FI_CSRN 256x4         A1:D256
#                Table1 5x3           B2:D6

# %%
b = IOBuffer()
show(b, "text/plain", xf[8][:,1:end])
s = String(take!(b))
println(s)
# Out:
# 256×4 Matrix{Any}:
#  0  430.7  499    944.9
#  0  430.7  499    944.9
#  0  430.7  499    944.9
#  0  430.7  499    944.9
#  0  395.9  451.9  863.7
#  0  375.2  423.8  821.5
#  0  360.5  408.6  785.4
#  0  355.7  393.7  759.6
#  0  334.6  378.5  727.9
#  0  323.6  360.9  701.6
#  0  311.7  344.5  663.5
#  0  296.7  334.6  640.4
#  0  281.5  320.6  612.9
#  0  271.6  304.3  584.9
#  0  264.9  303.2  564.5
#  0  254    291.2  543.1
#  0  247.9  281.8  527
#  0  235.4  278.6  510.1
#  0  231.5  276.8  502.5
#  0  221    268.1  488.8
#  0  214.4  260.9  471.3
#  0  205    253.8  460.8
#  0  204.4  251    449.4
#  0  200.7  245    440.1
#  0  194.8  239.6  430.4
#  0  190.5  233.5  422.4
#  0  185    230.5  411.3
#  0  183    223.5  403.7
#  0  174.5  219.4  395.1
#  0  170.3  216.7  392.4
#  0  167.5  213.7  386.9
#  0  160.7  210.1  378.1
#  0  156.4  208    372.5
#  0  152.7  202.9  363.7
#  0  146.6  200.7  356.2
#  0  145.1  199.6  349.6
#  0  145.9  195.9  343.7
# ...

# %%
ddfa
