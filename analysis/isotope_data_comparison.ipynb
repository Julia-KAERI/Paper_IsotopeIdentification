# %%
import numpy as np
import struct, os, sys
import matplotlib.pyplot as plt
import csv
import pandas as pd
import scipy.optimize as optimization
from datetime import datetime
from specs import *

# %% [markdown]
# # 광양 출장 일자
#
# - 2024년 10월 16일 ~ 10 월 17일
# - 2024년 11월 11일
# - 2024년 12월 18일 ~ 12 월 19일
#
# </br>
#
# # 목적
#
# - 대전 M1 에서 측정한 것과 광양에서 측정한 방사성 동위원소 측정 레퍼런스 데이터가 얼마나 차이가 있는지 보고자 하였다.
# - 백그라운드는 시간, 온도, 습도 등에 따라 변할 수 있기 때문에 Co60, Cs137, Am241 에서 백그라운드를 제거한 스펙트럼을 비교하였다.

# %%
isotope_data = get_ref_data()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.plot(isotope_data["daejeon"]["PN1"]["Am241"]-isotope_data["daejeon"]["PN1"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN1"]["Am241"]-isotope_data["kwangyang_20241016"]["PN1"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Am241"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241017")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Am241"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Am241 Spectrum - BKG, PN1")
plt.legend()
plt.subplot(122)
plt.plot(isotope_data["daejeon"]["PN2"]["Am241"]-isotope_data["daejeon"]["PN2"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN2"]["Am241"]-isotope_data["kwangyang_20241016"]["PN2"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Am241"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241017")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Am241"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Am241 Spectrum - BKG, PN2")
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.plot(isotope_data["daejeon"]["PN1"]["Co60"]-isotope_data["daejeon"]["PN1"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN1"]["Co60"]-isotope_data["kwangyang_20241016"]["PN1"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Co60"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Co60"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Co60 Spectrum - BKG, PN1")
plt.legend()
plt.subplot(122)
plt.plot(isotope_data["daejeon"]["PN2"]["Co60"]-isotope_data["daejeon"]["PN2"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN2"]["Co60"]-isotope_data["kwangyang_20241016"]["PN2"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Co60"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Co60"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Co60 Spectrum - BKG, PN2")
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.plot(isotope_data["daejeon"]["PN1"]["Cs137"]-isotope_data["daejeon"]["PN1"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN1"]["Cs137"]-isotope_data["kwangyang_20241016"]["PN1"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Cs137"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN1"]["Cs137"]-isotope_data["kwangyang_20241017"]["PN1"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Cs137 Spectrum - BKG, PN1")
plt.legend()
plt.subplot(122)
plt.plot(isotope_data["daejeon"]["PN2"]["Cs137"]-isotope_data["daejeon"]["PN2"]["BKG"], label="Daejeon")
plt.plot(isotope_data["kwangyang_20241016"]["PN2"]["Cs137"]-isotope_data["kwangyang_20241016"]["PN2"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Cs137"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241016")
plt.plot(isotope_data["kwangyang_20241017"]["PN2"]["Cs137"]-isotope_data["kwangyang_20241017"]["PN2"]["BKG"], label="Kwangyang_20241111")
plt.yscale("log", base=10)
plt.title("Cs137 Spectrum - BKG, PN2")
plt.legend()
